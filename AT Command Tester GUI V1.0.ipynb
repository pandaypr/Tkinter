# %%
from tkinter import *

root = Tk()
root.title('AT Command Tester')
root.iconbitmap('c:/Users/panp/esg-mobility-logo-white.ico')

#Variables
#COM = StringVar(root)
#COMPorts = {'COM1','COM2', 'COM3', 'COM4'}

#Frame1: COM Ports : Position (0,0)

def Frame1(COM, COMPort):
    print(COM)
    print(COMPort)
    COMPorts = COMPort
    COMFrame = LabelFrame(root, text = "COM Port", padx = 10, pady = 5)   #Inside of the frame Padding
    COMFrame.grid(row=0,column=0, padx=10, pady=10)      #Outside of the frame Padding
    COMValue = StringVar(root)
    COMValue.set(COM)

    #Buttons
    ConnectBtn = Button(COMFrame, text = " Connect ")
    DisconnectBtn = Button(COMFrame, text = "Disconnect")

    #For Input Fields and dropdown Menu
    #def display(COM, COMports):
    COMPort = OptionMenu(COMFrame, COMValue, *COMPorts)   #Use Entry to insert a input field
    COMPort.grid(row=0,column=1)

    BaudRate = Entry(COMFrame, width = 10, borderwidth = 2)   #Use Entry to insert a input field
    BaudRate.insert(0, '9600')    #Displays this msg on the input field itself


    ConnectBtn.grid(row=0,column=0)
    #COMPort.grid(row=0,column=1)
    DisconnectBtn.grid(row=1,column=0)
    BaudRate.grid(row=1,column=1)
#Frame1()

#Frame2: Various Buttons for Control : Position (1,0)
ButtonFrame = LabelFrame(root, padx = 10, pady = 5)   #Inside of the frame Padding
ButtonFrame.grid(row=1,column=0, padx=10, pady=10)      #Outside of the frame Padding

#Buttons
SendCommand = Button(ButtonFrame, text = "Send  \nButton")
AT = Button(ButtonFrame, text = "    AT   ")
Signal = Button(ButtonFrame, text = "Signal")
Network = Button(ButtonFrame, text = "Network")
Versions = Button(ButtonFrame, text = "Versions")
Reset = Button(ButtonFrame, text = "Reset")
Save = Button(ButtonFrame, text = "Save")
PowerOff = Button(ButtonFrame, text = "PowerOff")

#Inputs
SendCommandView = Entry(ButtonFrame, width = 15, borderwidth = 2,  font=('Helvetica', 24))
#SendCommandView.insert(0,'SendCommand')
ATView =  Entry(ButtonFrame, width = 20, borderwidth = 2) 
SignalView =  Entry(ButtonFrame, width = 20, borderwidth = 2) 
NetworkView =  Entry(ButtonFrame, width = 20, borderwidth = 2) 
VersionsView =  Entry(ButtonFrame, width = 20, borderwidth = 2) 
ResetView =  Entry(ButtonFrame, width = 20, borderwidth = 2) 
SaveView =  Entry(ButtonFrame, width = 20, borderwidth = 2) 
PowerOffView =  Entry(ButtonFrame, width = 20, borderwidth = 2) 

SendCommand.grid(row=0,column=0)
SendCommandView

AT.grid(row=1,column=0)
ATView

Signal.grid(row=2,column=0)
SignalView.grid(row=2,column=1)

Network.grid(row=3,column=0)
NetworkView.grid(row=3,column=1)

Versions.grid(row=4,column=0)
VersionsView.grid(row=4,column=1)

Reset.grid(row=5,column=0)
ResetView.grid(row=5,column=1)

Save.grid(row=6,column=0)
SaveView.grid(row=6,column=1)

PowerOff.grid(row=7,column=0)
PowerOffView.grid(row=7,column=1)

#Frame3: Modem Response : Position (0,1)
Modem = LabelFrame(root, padx = 10, pady = 5, width = 100, height = 150, background="bisque")   #Inside of the frame Padding
Modem.grid(row=0,column=1, rowspan=2, padx=5, pady=10)      #Outside of the frame Padding

quote = """HAMLET: To be, or not to be--that is the question:
Whether 'tis nobler in the mind to suffer
The slings and arrows of outrageous fortune
Or to take arms against a sea of troubles
And by opposing end them. To die, to sleep--
No more--and by a sleep to say we end
The heartache, and the thousand natural shocks
That flesh is heir to. 'Tis a consummation
Devoutly to be wished.HAMLET: To be, or not to be--that is the question:
Whether 'tis nobler in the mind to suffer
The slings and arrows of outrageous fortune
Or to take arms against a sea of troubles
And by opposing end them. To die, to sleep--
No more--and by a sleep to say we end
The heartache, and the thousand natural shocks
That flesh is heir to. 'Tis a consummation
Devoutly to be wished.HAMLET: To be, or not to be--that is the question:
Whether 'tis nobler in the mind to suffer
The slings and arrows of outrageous fortune
Or to take arms against a sea of troubles
And by opposing end them. To die, to sleep--
No more--and by a sleep to say we end
The heaThe heartache, and the thousand natural shocks
That flesh is heir to. 'Tis a consummation
Devoutly to be wished"""

OutputBox = Text(Modem, height=10, width=50)
OutputBox.pack()
OutputBox.insert(END, quote)
#OutputBox = Entry(Modem, width = 100, borderwidth = 2)   #Use Entry to insert a input field
#OutputBox.pack()
#OutputBox.insert(0, quote)    #Displays this msg on the input field itself

#classes::
class ATCommand:
    def __init__(self, ComPort, ComPorts):
        self.ComPort = ComPort
        self.ComPorts = ComPorts
        Frame1(self.ComPort, self.ComPorts)
        
    def RunAT(self, command):
        return command
    
    def RunATC(self, command, msg):
        return command
    
    
    def Display(self):
        ATView.insert(0,a.RunAT("AT"))
        SignalView.insert(0,a.RunAT("Signal"))
        NetworkView.insert(0,a.RunAT("Network"))
        VersionsView.insert(0,a.RunAT("Version"))
        ResetView.insert(0,a.RunAT("Reset"))
        SaveView.insert(0,a.RunAT("Save"))
        PowerOffView.insert(0,a.RunAT("PowerOff"))
        

b=['COM1', 'COM2','COM3']
a = ATCommand("COM1", b)

a.Display()

root.mainloop()
# Out:
# COM1
# ['COM1', 'COM2', 'COM3']

# %%
# Out:
#   File "<ipython-input-45-eee76296b491>", line 6
#     Power Off = Button(ButtonFrame, text = "    AT   ")
#           ^
# SyntaxError: invalid syntax

# %%
from tkinter import *

root = Tk()
root.title('Code')
root.iconbitmap('c:/Users/panp/Downloads/porsche_logo_icon_145784.ico')
root.geometry("670x400")

"""frame = LabelFrame(root, text = "This is my Frame... \n Hello", padx = 50, pady = 5)   #Inside of the frame Padding
#frame.pack(padx=100, pady=100)      #Outside of the frame Padding

"""
def Frame1(master, COM, COMPort):
    print(COM)
    print(COMPort)
    COMPorts = COMPort
    COMFrame = LabelFrame(master, text = "COM Port", padx = 10, pady = 5)   #Inside of the frame Padding
    COMFrame.grid(row=0,column=0, padx=10, pady=10)      #Outside of the frame Padding
    COMValue = StringVar(root)
    COMValue.set(COM)

    #Buttons
    ConnectBtn = Button(COMFrame, text = " Connect ")
    DisconnectBtn = Button(COMFrame, text = "Disconnect")

    #For Input Fields and dropdown Menu
    #def display(COM, COMports):
    COMPort = OptionMenu(COMFrame, COMValue, *COMPorts)   #Use Entry to insert a input field
    COMPort.grid(row=0,column=1)

    BaudRate = Entry(COMFrame, width = 10, borderwidth = 2)   #Use Entry to insert a input field
    BaudRate.insert(0, '9600')    #Displays this msg on the input field itself


    ConnectBtn.grid(row=0,column=0)
    #COMPort.grid(row=0,column=1)
    DisconnectBtn.grid(row=1,column=0)
    BaudRate.grid(row=1,column=1)


ButtonFrame = LabelFrame(root, padx=10, pady=5)  # Inside of the frame Padding
ButtonFrame.grid(row=1, column=0, padx=10, pady=10)  # Outside of the frame Padding

# Buttons
SendCommand = Button(ButtonFrame, text="Send  \nButton")
AT = Button(ButtonFrame, text="    AT   ")
Signal = Button(ButtonFrame, text="Signal")
Network = Button(ButtonFrame, text="Network")
Versions = Button(ButtonFrame, text="Versions")
Reset = Button(ButtonFrame, text="Reset")
Save = Button(ButtonFrame, text="Save")
PowerOff = Button(ButtonFrame, text="PowerOff")

# Inputs
SendCommandView = Entry(ButtonFrame, width=15, borderwidth=2, font=('Helvetica', 24))

ATView = Entry(ButtonFrame, width=20, borderwidth=2)
SignalView = Entry(ButtonFrame, width=20, borderwidth=2)
NetworkView = Entry(ButtonFrame, width=20, borderwidth=2)
VersionsView = Entry(ButtonFrame, width=20, borderwidth=2)
ResetView = Entry(ButtonFrame, width=20, borderwidth=2)
SaveView = Entry(ButtonFrame, width=20, borderwidth=2)
PowerOffView = Entry(ButtonFrame, width=20, borderwidth=2)

SendCommand.grid(row=0, column=0)
SendCommandView.grid(row=0, column=1)
SendCommandView.insert(0,'SendCommand')

AT.grid(row=1, column=0)
ATView.grid(row=1, column=1)

Signal.grid(row=2, column=0)
SignalView.grid(row=2, column=1)

Network.grid(row=3, column=0)
NetworkView.grid(row=3, column=1)

Versions.grid(row=4, column=0)
VersionsView.grid(row=4, column=1)

Reset.grid(row=5, column=0)
ResetView.grid(row=5, column=1)

Save.grid(row=6, column=0)
SaveView.grid(row=6, column=1)

PowerOff.grid(row=7, column=0)
PowerOffView.grid(row=7, column=1)


def Frame3(master):
    Modem = LabelFrame(master, padx=10, pady=5, width=100, height=150, background="bisque")  # Inside of the frame Padding
    Modem.grid(row=0, column=1, rowspan=2, padx=5, pady=10)  # Outside of the frame Padding

    quote = """HAMLET: To be, or not to be--that is the question:
    Whether 'tis nobler in the mind to suffer
    The slings and arrows of outrageous fortune
    Or to take arms against a sea of troubles
    And by opposing end them. To die, to sleep--
    No more--and by a sleep to say we end
    The heartache, and the thousand natural shocks
    That flesh is heir to. 'Tis a consummation
    Devoutly to be wished.HAMLET: To be, or not to be--that is the question:
    Whether 'tis nobler in the mind to suffer
    The slings and arrows of outrageous fortune
    Or to take arms against a sea of troubles
    And by opposing end them. To die, to sleep--
    No more--and by a sleep to say we end
    The heartache, and the thousand natural shocks
    That flesh is heir to. 'Tis a consummation
    Devoutly to be wished.HAMLET: To be, or not to be--that is the question:
    Whether 'tis nobler in the mind to suffer
    The slings and arrows of outrageous fortune
    Or to take arms against a sea of troubles
    And by opposing end them. To die, to sleep--
    No more--and by a sleep to say we end
    The heaThe heartache, and the thousand natural shocks
    That flesh is heir to. 'Tis a consummation
    Devoutly to be wished"""

    OutputBox = Text(Modem, height=10, width=50)
    OutputBox.pack()
    OutputBox.insert(END, quote)


class ATCommand:

    def __init__(self, master, ComPort, COMPorts):
        self.master = master
        self.ComPort = ComPort
        self.ComPorts = COMPorts
        Frame1(self.master, self.ComPort, self.ComPorts)
        #Frame2()
        Frame3(self.master)

    def RunAT(self, command):
            return command

    def RunATC(self, command, msg):
            return command

    def Display(self):
        ATView.insert(0, a.RunAT("AT"))
        SignalView.insert(0, a.RunAT("Signal"))
        NetworkView.insert(0, a.RunAT("Network"))
        VersionsView.insert(0, a.RunAT("Version"))
        ResetView.insert(0, a.RunAT("Reset"))
        SaveView.insert(0, a.RunAT("Save"))
        PowerOffView.insert(0, a.RunAT("PowerOff"))



b = ['COM1','COM2','COM3']
a = ATCommand(root, "COM1", b)
a.Display()
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-966ac8bb3b6d> in <module>
#     151
#     152 b = ['COM1','COM2','COM3']
# --> 153 a = ATCommand(root, "COM1", b)
#     154 a.Display()
#     155 root.mainloop()
#
# TypeError: __init__() takes 3 positional arguments but 4 were given

# %% [markdown]
# ## Class

# %%
import tkinter as tk

class Application(tk.Frame):
    def __init__(self, master=None):
        super().__init__(master)
        self.master = master
        self.pack()
        self.create_widgets()

    def create_widgets(self):
        self.hi_there = tk.Button(self)
        self.hi_there["text"] = "Hello World\n(click me)"
        self.hi_there["command"] = self.say_hi
        self.hi_there.pack(side="top")

        self.quit = tk.Button(self, text="QUIT", fg="red",
                              command=self.master.destroy)
        self.quit.pack(side="bottom")

    def say_hi(self):
        print("hi there, everyone!")

root = tk.Tk()
app = Application(master=root)
app.mainloop()
# Out:
# hi there, everyone!
# hi there, everyone!
# hi there, everyone!

# %%
# Out:
# Hi. The current entry content is: regergt
# Hi. The current entry content is: regergt

# %% [markdown]
# ## Display on Console APP::

# %%
import tkinter as tk
import time
import sys

class Display(tk.Frame):
    def __init__(self,parent=0):
       tk.Frame.__init__(self,parent)
       self.input = tk.Text(self, width=100, height=15)
       self.input.pack()
       self.doIt = tk.Button(self,text="URL to Hash", command=self.onEnter)
       self.doIt.pack()
       self.output = tk.Text(self, width=100, height=15)
       self.output.pack()
       sys.stdout = self
       self.pack()

    def onEnter(self):
        text_input = self.input.get(1.0,tk.END)
        product_url_list = text_input.split('\n')
        url_list_to_hash(product_url_list)

### I used the code below to somewhat successfully call the functions from another script
### but it did not solve my issue though.
        # p = subprocess.Popen(['python', './image_url_to_hash.py', self.input.get(1.0,"end-1c")],
        #              stdout=subprocess.PIPE,
        #              stderr=subprocess.STDOUT,
        #              )
        # for line in iter(p.stdout.readline, ''):
        #     print line

    def write(self, txt):
        self.output.insert(tk.END,str(txt))
#######This is the missing line!!!!:
        self.update_idletasks()

def input_to_hash(text_input):
    product_url_list = text_input.split('\n')
    ### This is just some dummy code to simulate the output.
    ### There is a delay is processing each url, but I would like to capture output as it's running
    for link in product_url_list:
        time.sleep(1)
        print(link)

if __name__ == '__main__':
    Display().mainloop()

# %% [markdown]
# ## Class app with a functionality

# %% [markdown]
# import tkinter as tk
#
# class Window(tk.Tk):
#     def __init__(self):
#         super().__init__()
#         self.title("Hello Tkinter")
#         self.label_text = tk.StringVar()
#         self.label_text.set("Choose One")
#
#         self.label = tk.Label(self, textvar=self.label_text)
#         self.label.pack(fill=tk.BOTH, expand=1, padx=100, pady=30)
#
#         hello_button = tk.Button(self, text="Say Hello", command=self.say_hello)
#         hello_button.pack(side=tk.LEFT, padx=(20, 0), pady=(0, 20))
#
#         goodbye_button = tk.Button(self, text="Say Goodbye", command=self.say_goodbye)
#         goodbye_button.pack(side=tk.RIGHT, padx=(0, 20), pady=(0, 20))
#
#     def say_hello(self):
#         self.label_text.set("Hello World")
#
#     def say_goodbye(self):
#         self.label_text.set("Goodbye! \n (Closing in 2 seconds)")
#         self.after(2000, self.destroy)
#
#
# if __name__ == "__main__":
#     window = Window()
#     window.mainloop()

# %% [markdown]
# ## Display Internet Status app working

# %%
import threading
from subprocess import Popen, PIPE
from time import sleep
import tkinter as tk
from tkinter import *
 
  
 
PROCESS = ['netstat','1']
class Console(tk.Frame):
    def __init__(self, master, *args, **kwargs):
        tk.Frame.__init__(self, master, *args, **kwargs)
        self.text = tk.Text(self, undo=False)
        self.text.pack(expand=True, fill="both")
        # run process in a thread to avoid blocking gui
        t = threading.Thread(target=self.execute)
        t.start()
  
  
    def display_text(self, p):
        display = ''
        lines_iterator = iter(p.stdout.readline, b"")
        for line in lines_iterator:
            if 'Active' in line:
                self.text.delete('1.0', END)
                self.text.insert(INSERT, display)
                display = ''
            display = display + line           
 
 
    def display_text2(self, p):
        while p.poll() is None:
            line = p.stdout.readline()
            if line != '':
                if 'Active' in line:
                    self.text.delete('1.0', END)
                self.text.insert(END, line)
                p.stdout.flush()       
 
 
    def execute(self):
            p = Popen(PROCESS,  universal_newlines=True,
                   stdout=PIPE, stderr=PIPE)
            print('process created with pid: {}'.format(p.pid))
            self.display_text(p)
 
   
if __name__ == "__main__":
    root = tk.Tk()
    root.title("netstat 1")
    Console(root).pack(expand=True, fill="both")
    root.mainloop()
# Out:
# process created with pid: 3912
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "C:\Users\panp\Anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\panp\Anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-1-6900e37314ff>", line 45, in execute
#   File "<ipython-input-1-6900e37314ff>", line 25, in display_text
#   File "C:\Users\panp\Anaconda3\lib\tkinter\__init__.py", line 3597, in delete
#     self.tk.call(self._w, 'delete', index1, index2)
# RuntimeError: main thread is not in main loop
