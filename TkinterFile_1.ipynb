# %% [markdown]
# ## Creating a simple Widget

# %%
from tkinter import *

root = Tk()

#Creating a Label Widget
myLabel1 = Label(root, text = 'Hello World').grid(row = 0, column = 0)
myLabel2 = Label(root, text = 'My Name is Panday').grid(row = 1, column = 5)
myLabel3 = Label(root, text = '')

#Solving it onto the screen
#myLabel.pack()                                    #packing the widget on to the display window

myLabel3.grid(row = 1, column = 1)                 #Rows and columns are relatively placed to each other



root.mainloop()

# %% [markdown]
# ## buttons

# %%
from tkinter import *

root = Tk()

def myClick():
    myLabel = Label(root, text = 'Look I Clicked a Button !')
    myLabel.pack()
    
    


myButton1 = Button(root, text = 'Click Me !', command = myClick)      #When calling the function, if you use paranthesis, 
                    #it calls the function in the beginning itself and do not call it later, so dont use it
buti = myButton1                 
myButton2 = Button(root, text = 'Click Me !', state = DISABLED, fg  = 'blue', bg = 'red')
myButton3 = Button(root, text = 'Click Me !', padx = 50, pady = 10, )

buti.pack()
myButton2.pack()
myButton3.pack()


root.mainloop()

# %% [markdown]
# ## Input Fields

# %%
from tkinter import *

root = Tk()

e = Entry(root, width = 50, borderwidth = 10)   #Use Entry to insert a input field
e.pack()
e.insert(0, 'Enter your Name:')    #Displays this msg on the input field itself


def myClick():
    myLabel = Label(root, text = 'Hello' + e.get()) 
    myLabel.pack()

myButton1 = Button(root, text = 'Click Me !', command = myClick).pack()      #When calling the function, if you use paranthesis, 
                    #it calls the function in the beginning itself and do not call it later, so dont use it



root.mainloop()

# %% [markdown]
# ## Calculator

# %%
from tkinter import *

root = Tk()
root.title('Calculator')


e = Entry(root, width = 35, borderwidth = 5)   #Use Entry to insert a input field
e.grid(row=0, column = 0, columnspan = 3, padx = 10, pady = 0)

#Button add Function  
def button_click(number):
    #e.delete(0, END)     #Delete the existing data on the display box 
    current = e.get()
    e.delete(0, END)
    e.insert(0, str(current) + str(number))
    
    return

def button_clear():
    e.delete(0, END)
    return

def button_add():
    first_number=int(e.get())
    global f_num
    global math
    math = 'addition'
    f_num = first_number
    e.delete(0, END)
    return

def button_equal():
    second_number = e.get()
    e.delete(0, END)
    if math == 'addition':
        e.insert(0,f_num + int(second_number))

    if math == 'subtraction':
        e.insert(0,f_num - int(second_number))
        
    if math == 'multiplication':
        e.insert(0,f_num * int(second_number))
        
    if math == 'divison':
        e.insert(0,f_num / int(second_number))
      
    return

def button_subract():
    first_number=int(e.get())
    global f_num
    global math
    math = 'subtraction'
    f_num = first_number
    e.delete(0, END)
    return

def button_multiply():
    first_number=int(e.get())
    global f_num
    global math
    math = 'multiplication'
    f_num = first_number
    e.delete(0, END)
    return

def button_divide():
    first_number=int(e.get())
    global f_num
    global math
    math = 'divison'
    f_num = first_number
    e.delete(0, END)
    return

#Define Buttons

button_1 = Button(root, text = '1', padx = 40, pady = 20, command = lambda: button_click(1))
button_2 = Button(root, text = '2', padx = 40, pady = 20, command = lambda: button_click(2))
button_3 = Button(root, text = '3', padx = 40, pady = 20, command = lambda: button_click(3))
button_4 = Button(root, text = '4', padx = 40, pady = 20, command = lambda: button_click(4))
button_5 = Button(root, text = '5', padx = 40, pady = 20, command = lambda: button_click(5))
button_6 = Button(root, text = '6', padx = 40, pady = 20, command = lambda: button_click(6))
button_7 = Button(root, text = '7', padx = 40, pady = 20, command = lambda: button_click(7))
button_8 = Button(root, text = '8', padx = 40, pady = 20, command = lambda: button_click(8))
button_9 = Button(root, text = '9', padx = 40, pady = 20, command = lambda: button_click(9))
button_0 = Button(root, text = '0', padx = 40, pady = 20, command = lambda: button_click(0))

button_add = Button(root, text = '+', padx = 39, pady = 20, command = button_add)
button_equal = Button(root, text = '=', padx = 91, pady = 20, command = button_equal)
button_clear = Button(root, text = 'Clear', padx = 79, pady = 20, command = button_clear)

button_subtract = Button(root, text = '-', padx = 41, pady = 20, command = button_subract)
button_multiply = Button(root, text = '*', padx = 40, pady = 20, command = button_multiply)
button_divide = Button(root, text = '/', padx = 41, pady = 20, command = button_divide)



#Put Buttons on the screen like  in a calculator

button_1.grid(row = 3, column =0)
button_2.grid(row = 3, column =1)
button_3.grid(row = 3, column =2)

button_4.grid(row = 2, column =0)
button_5.grid(row = 2, column =1)
button_6.grid(row = 2, column =2)

button_7.grid(row = 1, column = 0)
button_8.grid(row = 1, column = 1)
button_9.grid(row = 1, column = 2)
button_0.grid(row = 4, column = 0)

button_add.grid(row = 5, column = 0)
button_equal.grid(row = 5, column = 1, columnspan = 2)
button_clear.grid(row = 4, column = 1, columnspan = 2)

button_subtract.grid(row=6, column = 0)
button_multiply.grid(row=6, column = 1)
button_divide.grid(row=6, column = 2)



root.mainloop()

# %% [markdown]
# ## Icons, Images, and Exit Buttons

# %%
from tkinter import *
from PIL import ImageTk, Image

root = Tk()
root.title('Learn to Code Tkinter')
root.iconbitmap('c:/Users/panp/Downloads/porsche_logo_icon_145784.ico')

#button_quit = Button(root, text = 'Exit Program', command  = root.quit)  #Ending the Program
#button_quit.pack()

#diaply Images
my_img1 = ImageTk.PhotoImage(Image.open('c:/Users/panp/Downloads/Photos/1.jpg'))
my_img2 = ImageTk.PhotoImage(Image.open('c:/Users/panp/Downloads/Photos/2.jpg'))
my_img3 = ImageTk.PhotoImage(Image.open('c:/Users/panp/Downloads/Photos/3.jpg'))
my_img4 = ImageTk.PhotoImage(Image.open('c:/Users/panp/Downloads/Photos/4.jpg'))
my_img5 = ImageTk.PhotoImage(Image.open('c:/Users/panp/Downloads/Photos/5.jpg'))

image_list = [my_img1, my_img2, my_img3, my_img4, my_img5]

my_label1 = Label(image = my_img1)
my_label1.grid(row = 0, column = 0, columnspan = 3)

def forward(image_number):
    global my_label
    global button_forward
    global button_back
    my_label.grid_forget()



def back():
    global my_label
    global  button_forward
    global button_back
    
    #my_label.grid_forget()
        
        
    return


button_back = Button(root, text = '<<', command =back)
button_exit = Button(root, text = 'Exit Program', command = root.quit)
button_forward = Button(root, text = '>>', command = lambda: forward(2))

button_back.grid(row=1, column = 0)
button_exit.grid(row=1, column = 1)
button_forward.grid(row=1, column = 2)
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-fd52970547b3> in <module>
#      47 button_exit.grid(row=1, column = 1)
#      48 button_forward.grid(row=1, column = 2)
# ---> 49 root.mainloop()
#
# ~\Anaconda3\lib\tkinter\__init__.py in mainloop(self, n)
#    1418     def mainloop(self, n=0):
#    1419         """Call the mainloop of Tk."""
# -> 1420         self.tk.mainloop(n)
#    1421
#    1422     def quit(self):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Adding a status bar

# %%
from tkinter import *

root = Tk()

status = Label(root, text='Image')
status.grid(row = 2, column = 0, columnspan = 3)

root.mainloop()

# %% [markdown]
# ## Adding Frames

# %%
from tkinter import *
from PIL import ImageTk, Image

root = Tk()
root.title('Learn to Code Tkinter')
root.iconbitmap('c:/Users/panp/Downloads/porsche_logo_icon_145784.ico')

frame = LabelFrame(root, text = "This is my Frame... \n Hello", padx = 50, pady = 5)   #Inside of the frame Padding
frame.pack(padx=100, pady=100)      #Outside of the frame Padding

b1 = Button(frame, text = "Don't click Here")
b2 = Button(frame, text = "Or Here")
b1.grid(row=0,column=0)
b2.grid(row=1,column=0)


root.mainloop()

# %% [markdown]
# ## Radio Buttons

# %%
from tkinter import *
from PIL import ImageTk, Image

root = Tk()
root.title('Learn to Code Tkinter')
root.iconbitmap('c:/Users/panp/Downloads/porsche_logo_icon_145784.ico')

r = IntVar()
r.set("2")

def clicked(value):
    myLabel = Label(root, text=value)
    myLabel.pack()
    
Radiobutton(root, text="option1", variable = r, value = 1, command = lambda: clicked(r.get())).pack()
Radiobutton(root, text="option2", variable = r, value = 2, command = lambda: clicked(r.get())).pack()
Radiobutton(root, text="option3", variable = r, value = 3, command = lambda: clicked(r.get())).pack()
Radiobutton(root, text="option4", variable = r, value = 4, command = lambda: clicked(r.get())).pack()
Radiobutton(root, text="option5", variable = r, value = 5, command = lambda: clicked(r.get())).pack()

myLabel = Label(root, text=r.get())
myLabel.pack()

myButton  = Button(root, text = "Don't click Here", command = lambda: clicked(r.get())).pack()


root.mainloop()

# %% [markdown]
# ## Radio Buttons with For Loop

# %%
from tkinter import *
from PIL import ImageTk, Image

root = Tk()
root.title('Learn to Code Tkinter')
root.iconbitmap('c:/Users/panp/Downloads/porsche_logo_icon_145784.ico')

    
MODES = [
    ("Pepperoni", "Pepperoni"),
    ("Cheese", "Cheese"),
    ("Mushroom", "Mushroom"),
    ("Onion", "Onion"),
]

pizza = StringVar()
pizza.set("Pepproni")

for text, mode in MODES:     
    Radiobutton(root, text = text, variable =pizza, value = mode).pack(anchor=W)   #Anchor is used to allign the Radio Buttons
    #Since we didn't use command: lambadam it won't change the value when changed, instead when the button is clicked
    
def clicked(value):
    myLabel = Label(root, text=value)
    myLabel.pack()
    
    

myLabel = Label(root, text=pizza.get())
myLabel.pack()

myButton  = Button(root, text = "Don't click Here", command = lambda: clicked(pizza.get())).pack()


root.mainloop()

# %% [markdown]
# ## Message Box - PopUP

# %%
from tkinter import *
from PIL import ImageTk, Image
from tkinter import messagebox

root = Tk()
root.title('Learn to Code Tkinter')
root.iconbitmap('c:/Users/panp/Downloads/porsche_logo_icon_145784.ico')

#showinfo, showwarning, showerror, askquestion, askokcancel, askyesno
def popup():
    response = messagebox.askyesno("This is my Popup!","Hello World")
    Label(root, text = response).pack()
    if response == 1:
        Label(root, text = "You clicked Yes!").pack()
    else:
        Label(root, text = "You clicked No!").pack()
        
        

Button(root, text="Popup", command = popup).pack()


root.mainloop()

# %% [markdown]
# ## Create new window

# %%
from tkinter import *
from PIL import ImageTk, Image
from tkinter import messagebox

root = Tk()
root.title('Learn to Code Tkinter')
root.iconbitmap('c:/Users/panp/Downloads/porsche_logo_icon_145784.ico')

def open():
    top = Toplevel()
    top.title("my second Window")
    lbl = Label(top, text = "Hellow World!").pack()
    
btn = Button(root, text="open Second Window", command = open).pack()


root.mainloop()

# %% [markdown]
# ## Open File with File Dialog

# %%
from tkinter import *
from PIL import ImageTk, Image
from tkinter import filedialog

root = Tk()
root.title('Learn to Code Tkinter')
root.iconbitmap('c:/Users/panp/Downloads/porsche_logo_icon_145784.ico')

root.filename = filedialog.askopenfilename(initialdir = "C:/Users/panp/Downloads/Photos", title = "Select a File", filetypes = (("png files", "*.png"),( "all Files", )))


root.mainloop()
# Out:
#   File "<ipython-input-9-24047368def7>", line 9
#     root.filename = filedialog.askopenfilename(initialdir = "C:/Users/panp/Downloads/Photos", title = "Select a File", filetypes = (("png files", "*.png"),( "all Files",*.* )))
#                                                                                                                                                                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Sliders with Tkinter

# %%
from tkinter import *
from PIL import ImageTk, Image


root = Tk()
root.title('Learn to Code Tkinter')
root.iconbitmap('c:/Users/panp/Downloads/porsche_logo_icon_145784.ico')
root.geometry("400x400")

vertical = Scale(root, from_ = 0, to = 200)
vertical.pack()

horizontal =  Scale(root, from_ = 0, to = 200, orient = HORIZONTAL)
horizontal.pack()

my_label = Label(root, text = horizontal.get()).pack()

def slide():
    my_label + Label(root, text = horizontal.get()).pack()

my_btn = Button(root, text="Click Me!", command = slide ).pack()
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\panp\Anaconda3\lib\tkinter\__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "<ipython-input-5-6b4ed069263b>", line 19, in slide
#     my_label + Label(root, text = horizontal.get()).pack()
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %% [markdown]
# ## Resize Entry Box By Height

# %%
from tkinter import *

root = Tk()
root.title('Code')
root.iconbitmap('c:/Users/panp/Downloads/porsche_logo_icon_145784.ico')
root.geometry("400x400")

def myClick():
    hello = "Hello" + e.get()
    myLabel + Label(root, text = hello)
    myLabel.pack(pady=10)
    
myButton = Button(root, text = 'Insert Your Name', command = myClick).grid(row = 0, column =0)   #When calling the function, if you use paranthesis, 
                    #it calls the function in the beginning itself and do not call it later, so dont use it
    
e = Entry(root, width = 20, font=('Helvetica', 24))   #Use Entry to insert a input field
e.grid(row = 0, column =1, padx = 10)






root.mainloop()

# %% [markdown]
# ## List for recently used AT Commands

# %%
import tkinter as tk

chiefs = [
    'Sitting Bull', 'Geronimo', 'Tecumseh', 'Pontiac', 
    'Red Cloud', 'Crazy Horse', 'Cochise', 'Red Jacket', 
    'Red Czar', 'Red Czechoslovakian']

def match_string():
    hits = []
    got = auto.get()
    for item in chiefs:
        if item.startswith(got):
            hits.append(item)
    return hits    

def get_typed(event):
    if len(event.keysym) == 1:
        hits = match_string()
        show_hit(hits)

def show_hit(lst):
    if len(lst) == 1:
        auto.set(lst[0])
        detect_pressed.filled = True

def detect_pressed(event):    
    key = event.keysym
    if len(key) == 1 and detect_pressed.filled is True:
        pos = autofill.index(tk.INSERT)
        autofill.delete(pos, tk.END)

detect_pressed.filled = False

root = tk.Tk()

auto = tk.StringVar()

autofill = tk.Entry(
    root, 
    font=('tacoma', 30),
    bg='black',
    insertbackground='white',
    fg='white',
    textvariable=auto)
autofill.grid()
autofill.focus_set()
autofill.bind('<KeyRelease>', get_typed)
autofill.bind('<Key>', detect_pressed)

root.mainloop()

# %% [markdown]
# ## FRAME

# %%
from tkinter import *

root = Tk()
frame = Frame(root)
frame.pack()

bottomframe = Frame(root)
bottomframe.pack( side = BOTTOM )

redbutton = Button(frame, text="Red", fg="red")
redbutton.pack( side = LEFT)

greenbutton = Button(frame, text="Brown", fg="brown")
greenbutton.pack( side = LEFT )

bluebutton = Button(frame, text="Blue", fg="blue")
bluebutton.pack( side = LEFT )

blackbutton = Button(bottomframe, text="Black", fg="black")
blackbutton.pack( side = BOTTOM)

root.mainloop()

# %% [markdown]
# ## Class:

# %%
from tkinter import *

root = Tk()
root.title('Code')
root.iconbitmap('c:/Users/panp/Downloads/porsche_logo_icon_145784.ico')
root.geometry("500x500")


"""frame = LabelFrame(root, text = "This is my Frame... \n Hello", padx = 50, pady = 5)   #Inside of the frame Padding
#frame.pack(padx=100, pady=100)      #Outside of the frame Padding

"""

class Elder:
    
    def __init__(self, master,COM, COMPort):
        self.master = master
        
        COMPorts = COMPort
        COMValue = StringVar(root)
        COMValue.set(COM)
        COMFrame = LabelFrame(self.master, text = "COM Port", padx = 10, pady = 5, bg = "red")
        COMFrame.grid(row=0,column=0, padx=10, pady=10)
        
        ConnectBtn = Button(COMFrame, text = " Connect ")
        DisconnectBtn = Button(COMFrame, text = "Disconnect")

        #For Input Fields and dropdown Menu
        #def display(COM, COMports):
        COMPort = OptionMenu(COMFrame, COMValue, *COMPorts)   #Use Entry to insert a input field
        COMPort.grid(row=0,column=1)

        BaudRate = Entry(COMFrame, width = 10, borderwidth = 2)   #Use Entry to insert a input field
        BaudRate.insert(0, '9600')    #Displays this msg on the input field itself


        ConnectBtn.grid(row=0,column=0)
        #COMPort.grid(row=0,column=1)
        DisconnectBtn.grid(row=1,column=0)
        BaudRate.grid(row=1,column=1)
        
        myFrame1 = LabelFrame(master,  text = "This is my", bg = "red", padx = 10, pady = 5)
        myFrame1.grid(row=1,column=0, padx=10, pady=10)
        
        self.myButton = Button(myFrame1, text = "Click !")
        self.myButton.pack(pady = 20)
        
        myFrame2 = LabelFrame(master,  text = "This is ",bg = "red", padx = 10, pady = 5)
        myFrame2.grid(row=0,column=1, rowspan=2, padx=5, pady=10)
        
        self.myButton = Button(myFrame2, text = "Click Me!")
        self.myButton.pack(pady = 20)

b=['COM1', 'COM2','COM3']
a = Elder(root,"COM1", b)

root.mainloop()

# %% [markdown]
# ## Class 2

# %%
import tkinter as tk




class TestFrame(tk.Frame):
    def __init__(self):
        super().__init__()

class loop(tk.Tk):    
    def __init__(self):
        super().__init__()
        self.title("Test Application")
        self.geometry("800x400")
        self.testFrame1 = TestFrame()
        self.testFrame1.grid(row=0, column=0,  columnspan=3, sticky='nsew')
        e = tk.Entry(self.testFrame1, width=15, borderwidth=2, font=('Helvetica', 24))
        e.grid(row=0, column=1)
        hello_button = tk.Button(self.testFrame1, text="Say Hello", command = lambda: self.Click(e)).grid()
        #a = e.get()
        #print(a)
        #hello_button.command = self.Click(e)
    
    def Click(self, e):
        b=e.get()
        print(b)



loop().mainloop()

# %% [markdown]
# ## Database

# %%
from tkinter import *

root = Tk()
root.title('Code')
root.iconbitmap('c:/Users/panp/Downloads/porsche_logo_icon_145784.ico')
root.geometry("400x400")



root.mainloop()

# %% [markdown]
# ## Terminal Output

# %%
import tkinter as tk
import time
import sys

class Display(tk.Frame):
    def __init__(self,parent=0):
       tk.Frame.__init__(self,parent)
       self.input = tk.Text(self, width=100, height=15)
       self.input.pack()
       self.doIt = tk.Button(self,text="URL to Hash", command=self.onEnter)
       self.doIt.pack()
       self.output = tk.Text(self, width=100, height=15)
       self.output.pack()
       sys.stdout = self
       self.pack()

    def onEnter(self):
        text_input = self.input.get(1.0,tk.END)
        product_url_list = text_input.split('\n')
        url_list_to_hash(product_url_list)

### I used the code below to somewhat successfully call the functions from another script
### but it did not solve my issue though.
        # p = subprocess.Popen(['python', './image_url_to_hash.py', self.input.get(1.0,"end-1c")],
        #              stdout=subprocess.PIPE,
        #              stderr=subprocess.STDOUT,
        #              )
        # for line in iter(p.stdout.readline, ''):
        #     print line

    def write(self, txt):
        self.output.insert(tk.END,str(txt))
#######This is the missing line!!!!:
        self.update_idletasks()

def input_to_hash(text_input):
    product_url_list = text_input.split('\n')
    ### This is just some dummy code to simulate the output.
    ### There is a delay is processing each url, but I would like to capture output as it's running
    for link in product_url_list:
        time.sleep(1)
        print(link)

if __name__ == '__main__':
    Display().mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\panp\Anaconda3\lib\tkinter\__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "<ipython-input-3-d1204a454011>", line 20, in onEnter
#     url_list_to_hash(product_url_list)
# NameError: name 'url_list_to_hash' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\panp\Anaconda3\lib\tkinter\__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "<ipython-input-3-d1204a454011>", line 20, in onEnter
#     url_list_to_hash(product_url_list)
# NameError: name 'url_list_to_hash' is not defined
